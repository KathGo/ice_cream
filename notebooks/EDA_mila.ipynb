# %% [markdown]
# # SeaIce-Prediction

# %% [markdown]
# ### how does the extantion of seaice influence the climate?
# - discription of topic and goal of the project
# - for what/whom is it important to know?

# %%
#import of the neccessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ftplib import FTP
import os

# %%
df_n = pd.read_csv('../data/N_seaice_extent_daily_v3.0.csv')
df_n.head()
# Out:
#    Year   Month   Day       Extent      Missing  \
# 0  YYYY      MM    DD   10^6 sq km   10^6 sq km
# 1  1978      10    26       10.231        0.000
# 2  1978      10    28       10.420        0.000
# 3  1978      10    30       10.557        0.000
# 4  1978      11    01       10.670        0.000
#
#                                          Source Data
# 0   Source data product web sites: http://nsidc.o...
# 1   ['/ecs/DP1/PM/NSIDC-0051.001/1978.10.26/nt_19...
# 2   ['/ecs/DP1/PM/NSIDC-0051.001/1978.10.28/nt_19...
# 3   ['/ecs/DP1/PM/NSIDC-0051.001/1978.10.30/nt_19...
# 4   ['/ecs/DP1/PM/NSIDC-0051.001/1978.11.01/nt_19...

# %%
##the same for the southern hemisphere
## 1. Set the directory you would like to download the files to
#destdir='../data'

## 2. Set the path to the FTP directory that contains the data you wish to download.
## This example is for the daily southern hemisphere data from the Sea Ice Index
## https://nsidc.org/data/g02135
#directory = '/DATASETS/NOAA/G02135/south/daily/data'

## 3. Set the password which will be your email address
#password = 'kaddygorrissen@gmail.com'

############################################
### Don't need to change this code below ###
############################################
## FTP server
#ftpdir = 'sidads.colorado.edu'

##Connect and log in to the FTP
#print('Logging in')
#ftp = FTP(ftpdir)
#ftp.login('anonymous',password)

## Change to the directory where the files are on the FTP
#print('Changing to '+ directory)
#ftp.cwd(directory)

## Get a list of the files in the FTP directory
#files = ftp.nlst()
#files = files[2:]
#print(files)

##Change to the destination directory on own computer where you want to save the files
#os.chdir(destdir)

##Download all the files within the FTP directory
#for file in files:
#    print('Downloading...' + file)
#    ftp.retrbinary('RETR ' + file, open(file, 'wb').write)

##Close the FTP connection
#ftp.quit()
# Out:
# Logging in
# Changing to /DATASETS/NOAA/G02135/south/daily/data
# ['S_seaice_extent_climatology_1981-2010_v3.0.csv', 'S_seaice_extent_daily_v3.0.csv', 'S_seaice_extent_daily_v3.0.csv.bak']
# Downloading...S_seaice_extent_climatology_1981-2010_v3.0.csv
# Downloading...S_seaice_extent_daily_v3.0.csv
# Downloading...S_seaice_extent_daily_v3.0.csv.bak
# '221-Goodbye. You uploaded 0 and downloaded 3848 kbytes.\n221 Logout.'

# %%
df_s = pd.read_csv('../data/S_seaice_extent_daily_v3.0.csv')
df_s.head()
# Out:
#    Year   Month   Day       Extent      Missing  \
# 0  YYYY      MM    DD   10^6 sq km   10^6 sq km
# 1  1978      10    26       17.624        0.000
# 2  1978      10    28       17.803        0.000
# 3  1978      10    30       17.670        0.000
# 4  1978      11    01       17.527        0.000
#
#                                          Source Data
# 0   Source data product web sites: http://nsidc.o...
# 1   ['/ecs/DP1/PM/NSIDC-0051.001/1978.10.26/nt_19...
# 2   ['/ecs/DP1/PM/NSIDC-0051.001/1978.10.28/nt_19...
# 3   ['/ecs/DP1/PM/NSIDC-0051.001/1978.10.30/nt_19...
# 4   ['/ecs/DP1/PM/NSIDC-0051.001/1978.11.01/nt_19...

# %%
raw_df = pd.read_csv('../data/masie_4km_allyears_extent_sqkm.csv',sep=",")
raw_df.head(10)
# Out:
#     yyyyddd   (0) Northern_Hemisphere   (1) Beaufort_Sea   (2) Chukchi_Sea  \
# 0   2006001               13034723.95         1069710.81         966006.16
# 1   2006002               13034723.95         1069710.81         966006.16
# 2   2006003               13170663.24         1069710.81         966006.16
# 3   2006004               13409715.53         1069710.81         966006.16
# 4   2006005               13416779.12         1069710.81         966006.16
# 5   2006006               13465566.44         1069710.81         966006.16
# 6   2006007               13510769.37         1069710.81         966006.16
# 7   2006008               13536736.84         1069710.81         966006.16
# 8   2006009               13536887.64         1069710.81         966006.16
# 9   2006010               13505426.35         1069710.81         966006.16
#
#     (3) East_Siberian_Sea   (4) Laptev_Sea   (5) Kara_Sea   (6) Barents_Sea  \
# 0              1087102.72        897773.37      901663.34         432629.77
# 1              1087102.72        897773.37      901663.34         432629.77
# 2              1087102.72        897773.37      901663.34         432629.77
# 3              1087102.72        897773.37      906439.04         458823.88
# 4              1087102.72        897773.37      908697.29         474574.82
# 5              1087102.72        897773.37      909717.79         474574.82
# 6              1087102.72        897773.37      927602.17         474574.82
# 7              1087102.72        897773.37      927602.17         474574.82
# 8              1087102.72        897773.37      927602.17         474574.82
# 9              1087102.72        897773.37      933999.29         448185.27
#
#     (7) Greenland_Sea   (8) Baffin_Bay_Gulf_of_St._Lawrence  \
# 0           550158.41                             831365.98
# 1           550158.41                             831365.98
# 2           595342.42                             855907.47
# 3           605747.86                             980253.85
# 4           600826.71                             970631.09
# 5           595938.39                             992651.97
# 6           588978.00                            1000360.27
# 7           590029.18                            1005790.38
# 8           590029.18                            1005790.38
# 9           588279.64                            1016857.87
#
#     (9) Canadian_Archipelago   (10) Hudson_Bay   (11) Central_Arctic  \
# 0                  852715.31        1260715.19            3225371.74
# 1                  852715.31        1260715.19            3225371.74
# 2                  852715.31        1260779.00            3240507.71
# 3                  852715.31        1260779.00            3240326.47
# 4                  852715.31        1260779.00            3240326.47
# 5                  852715.31        1260779.00            3240326.47
# 6                  852715.31        1260779.00            3240326.47
# 7                  852715.31        1260779.00            3240326.47
# 8                  852715.31        1260779.00            3240326.47
# 9                  852715.31        1260779.00            3217380.82
#
#     (12) Bering_Sea   (13) Baltic_Sea   (14) Sea_of_Okhotsk   (15) Yellow_Sea  \
# 0         639590.07          11408.53             287369.54          12152.54
# 1         639590.07          11408.53             287369.54          12152.54
# 2         666030.40          11408.53             311943.21          12152.54
# 3         683780.08          11408.53             372868.02           6989.96
# 4         683795.38          21311.46             363515.34           8240.73
# 5         685430.49          21327.46             385908.77          14830.45
# 6         690278.54          21327.46             407631.37          14830.45
# 7         692832.54          21327.46             424563.54          14830.45
# 8         692832.54          21478.25             424563.54          14830.45
# 9         705348.17          21493.81             414191.19          14830.45
#
#     (16) Cook_Inlet
# 0           6420.96
# 1           6420.96
# 2           6420.96
# 3           6420.96
# 4           8202.95
# 5           8202.95
# 6           8202.95
# 7           8202.95
# 8           8202.95
# 9           8202.95

# %% [markdown]
# Plotting time series

# %%
# Main data packages. 
import numpy as np
import pandas as pd

# Data Viz. 
import statsmodels.formula.api as smf
from statsmodels.tsa.seasonal import seasonal_decompose
from scipy.ndimage import gaussian_filter
from calendar import monthrange
from calendar import month_name


import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style(
    style='darkgrid', 
    rc={'axes.facecolor': '.9', 'grid.color': '.8'}
)
NF_ORANGE = '#ff5a36'
NF_BLUE = '#163251'
cmaps_hex = ['#193251','#FF5A36','#1E4485', '#99D04A','#FF5A36', '#DB6668']
sns.set_palette(palette=cmaps_hex)
sns_c = sns.color_palette(palette=cmaps_hex)
# %matplotlib inline
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

plt.rcParams['figure.figsize'] = [12, 6]
plt.rcParams['figure.dpi'] = 100
plt.rcParams.update({'figure.facecolor':'white'})

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5865 entries, 0 to 5864
# Data columns (total 18 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0    yyyyddd                              5865 non-null   int64
#  1    (0) Northern_Hemisphere              5865 non-null   float64
#  2    (1) Beaufort_Sea                     5865 non-null   float64
#  3    (2) Chukchi_Sea                      5865 non-null   float64
#  4    (3) East_Siberian_Sea                5865 non-null   float64
#  5    (4) Laptev_Sea                       5865 non-null   float64
#  6    (5) Kara_Sea                         5865 non-null   float64
#  7    (6) Barents_Sea                      5865 non-null   float64
#  8    (7) Greenland_Sea                    5865 non-null   float64
#  9    (8) Baffin_Bay_Gulf_of_St._Lawrence  5865 non-null   float64
#  10   (9) Canadian_Archipelago             5865 non-null   float64
#  11   (10) Hudson_Bay                      5865 non-null   float64
#  12   (11) Central_Arctic                  5865 non-null   float64
#  13   (12) Bering_Sea                      5865 non-null   float64
#  14   (13) Baltic_Sea                      5865 non-null   float64
#  15   (14) Sea_of_Okhotsk                  5865 non-null   float64
#  16   (15) Yellow_Sea                      5865 non-null   float64
#  17   (16) Cook_Inlet                      5865 non-null   float64
# dtypes: float64(17), int64(1)
# memory usage: 824.9 KB

# %%
from datetime import datetime
date =[]
date_day =[]
date_month=[]
date_year=[]
for i in range(0, len(raw_df[' yyyyddd'])):
   day_year=str(raw_df[' yyyyddd'][i])
   day_num = day_year[-3:] 
   year_num = day_year[:4] 
   #print(year_num) 
   #print("The day number : " + str(day_num))
  
   # adjusting day num
   day_num.rjust(3 + len(day_num), '0')
   
   # converting to date
   res = datetime.strptime(year_num + "-" + day_num, "%Y-%j").strftime("%m-%d-%Y")
   date.append(res)
   str_day=str(res)
   #print(res)
   date_day.append(res[3:5])
   date_year.append(res[6:])
   date_month.append(res[0:2])
raw_df = raw_df.assign(
    date = date,
    day = date_day,
    month = date_month,
    year = date_year
    
    )
raw_df.head(10)

raw_df=raw_df.drop([' yyyyddd'], axis=1)

# %%
raw_df= raw_df.rename(columns={' (0) Northern_Hemisphere': 'Northern_Hemisphere', ' (1) Beaufort_Sea' : 'Beaufort_Sea' , ' (2) Chukchi_Sea' :' Chukchi_Sea',
       ' (3) East_Siberian_Sea' :'East_Siberian_Sea', ' (4) Laptev_Sea' : 'Laptev_Sea', ' (5) Kara_Sea' : 'Kara_Sea', ' (6) Barents_Sea': 'Barents_Sea',
       ' (7) Greenland_Sea': 'Greenland_Sea ',' (8) Baffin_Bay_Gulf_of_St._Lawrence': 'Baffin_Bay_Gulf_of_St._Lawrence', ' (9) Canadian_Archipelago': 'Canadian_Archipelago', ' (10) Hudson_Bay': 'Hudson_Bay',
       ' (11) Central_Arctic':'Central_Arctic', 
       ' (12) Bering_Sea': 'Bering_Sea', ' (13) Baltic_Sea':'Baltic_Sea', ' (14) Sea_of_Okhotsk' :'Sea_of_Okhotsk',
       ' (15) Yellow_Sea': 'Yellow_Sea', ' (16) Cook_Inlet':'Cook_Inlet'})
raw_df.columns
# Out:
# Index(['Northern_Hemisphere', 'Beaufort_Sea', ' Chukchi_Sea',
#        'East_Siberian_Sea', 'Laptev_Sea', 'Kara_Sea', 'Barents_Sea',
#        'Greenland_Sea ', 'Baffin_Bay_Gulf_of_St._Lawrence',
#        'Canadian_Archipelago', 'Hudson_Bay', 'Central_Arctic', 'Bering_Sea',
#        'Baltic_Sea', 'Sea_of_Okhotsk', 'Yellow_Sea', 'Cook_Inlet', 'date',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
raw_df['datetime'] = pd.to_datetime(raw_df.date, format='%m-%d-%Y')
# Convert timestamp to datetime object
raw_df = raw_df.assign(
    timestamp = lambda x: pd.to_datetime(x['datetime']), 
    date = lambda x: x['timestamp'].dt.date,
    year = lambda x: x['timestamp'].dt.year,
    month = lambda x: x['timestamp'].dt.month,
    day = lambda x: x['timestamp'].dt.day,
    dayofyear = lambda x: x['timestamp'].dt.dayofyear,
    hour = lambda x: x['timestamp'].dt.hour,
)

# %% [markdown]
# The ice coverage in Sea of Okhotsk shows the maximum ice coverage in range between 0,78 and 1,3 + 10^6 sqkm.
#
# In the year 2015 we have the smallest ice coverage maximum.

# %%
fig, ax = plt.subplots()
sns.lineplot(x=raw_df['timestamp'], y=raw_df['Sea_of_Okhotsk'] , data=raw_df, ax=ax)
ax.set(title='Sea ice coverage of Okhotst sea', ylabel=r'sqkm')
# Out:
# [Text(0.5, 1.0, 'Sea ice coverage of Okhotst sea'), Text(0, 0.5, 'sqkm')]

# %%
fig, ax = plt.subplots()
sns.lineplot(x=raw_df['year'], y=raw_df['Sea_of_Okhotsk'] , data=raw_df, ax=ax)
ax.set(title='Sea ice coverage of Okhotst sea', ylabel=r'sqkm')
# Out:
# [Text(0.5, 1.0, 'Sea ice coverage of Okhotst sea'), Text(0, 0.5, 'sqkm')]

# %% [markdown]
# For the sea ice coverage we can see an annual cycle with a maximum in march and minimum in summer month from june to october

# %%
# Plot yearly seasonality

fig, ax = plt.subplots() 

pd.pivot_table(data=raw_df[['Sea_of_Okhotsk']], index=raw_df['month'], columns=raw_df['year']) \
    .plot(cmap='viridis', alpha=0.5, ax=ax)

ax.legend(title='year', loc='center left', bbox_to_anchor=(1, 0.5))
ax.set(title='Sea of Okhotsk sea ice coverage', ylabel='sqkm');

# %%
# Polar plot for seasonality 
ax = plt.subplot(111, projection='polar')

# Convert and plot data
raw_df \
    .assign(day_of_year_cyclic = lambda x: x['dayofyear'].transform(lambda x: 2*np.pi*x/365.5)) \
    .pipe((sns.lineplot, 'data'), 
        x='day_of_year_cyclic', 
        y='Sea_of_Okhotsk', 
        hue='month',
        palette=sns.color_palette("husl", 12),
        ax=ax
    )

plot_year = 2012
days_per_month=[monthrange(plot_year, i)[1] for i in range(1,13)]                    #findout how many days each month has  
month_theta=(np.array(days_per_month).cumsum()-days_per_month[0]+1)*2*np.pi/365.5 #find the starting day for each month and turn it into an angle 
month_label=[month_name[i] for i in range(1,13)]
month_label=[label+'\n(Day ' +str(int(month_theta[ind]*365.5/np.pi/2)) +')' for ind,label in enumerate(month_label)]

ax.set_facecolor('white')
ax.spines.clear()
ax.set_xticks(month_theta)
ax.set_xticklabels(month_label)
ax.set_ylim(-1,1500000)
ax.set_yticks(yt:=[0,500000,1000000,1500000])
ax.set_yticklabels([str(t)+' sqkm' for t in yt], rotation = 45)
ax.set_rlabel_position(12) 
ax.xaxis.set_tick_params(which='major',pad=10)

ax.set_rorigin(-5)
ax.set_ylabel('')
ax.set_xlabel('')
ax.legend().set_visible(False)

ax.set_title('Sea of Okhotst sea ice coverage ', va='bottom');
ax.figure.set_figwidth(12)
ax.figure.set_figheight(12)

ax.figure.savefig("Polar_plot.png")

# %%
df_2016=raw_df[raw_df['year']==2016]
df_2016.head(10)
# Out:
#       Northern_Hemisphere  Beaufort_Sea   Chukchi_Sea  East_Siberian_Sea  \
# 3612          13095244.88    1070444.98     965989.09         1087119.96
# 3613          13359000.37    1070444.98     965989.09         1087119.96
# 3614          13474043.32    1070444.98     965989.09         1087119.96
# 3615          13558970.55    1070444.98     965989.09         1087119.96
# 3616          13803671.30    1070444.98     965989.09         1087119.96
# 3617          13749092.15    1070444.98     965989.09         1087119.96
# 3618          13701158.13    1070444.98     965989.09         1087119.96
# 3619          13736694.98    1070444.98     965989.09         1087119.96
# 3620          13618739.42    1070444.98     965989.09         1087119.96
# 3621          13603509.32    1070444.98     965989.09         1087119.96
#
#       Laptev_Sea   Kara_Sea  Barents_Sea  Greenland_Sea   \
# 3612    897809.2  875846.46    356415.06       557953.54
# 3613    897809.2  888530.76    384514.62       585920.60
# 3614    897809.2  895976.37    388261.10       560955.78
# 3615    897809.2  897188.60    387680.89       576571.07
# 3616    897809.2  934988.15    428712.96       626840.10
# 3617    897809.2  897962.57    424770.49       627515.15
# 3618    897809.2  899336.37    425297.57       620765.22
# 3619    897809.2  909354.89    400293.43       622238.03
# 3620    897809.2  893384.39    412279.06       590394.51
# 3621    897809.2  893384.39    412279.06       590394.51
#
#       Baffin_Bay_Gulf_of_St._Lawrence  Canadian_Archipelago  ...  Yellow_Sea  \
# 3612                       1181296.77             853178.45  ...     4312.40
# 3613                       1244897.89             853178.45  ...     4312.40
# 3614                       1265837.06             853178.45  ...     4312.40
# 3615                       1320324.87             853178.45  ...     4312.40
# 3616                       1327474.99             853178.45  ...     5062.91
# 3617                       1319634.53             853178.45  ...     5062.91
# 3618                       1294825.79             853178.45  ...     5062.91
# 3619                       1299836.68             853178.45  ...     5938.30
# 3620                       1298564.70             853178.45  ...     5925.41
# 3621                       1284136.28             853178.45  ...     5925.41
#
#       Cook_Inlet        date  day  month  year   datetime  timestamp  \
# 3612     4489.81  2016-01-01    1      1  2016 2016-01-01 2016-01-01
# 3613     4489.81  2016-01-02    2      1  2016 2016-01-02 2016-01-02
# 3614     4489.81  2016-01-03    3      1  2016 2016-01-03 2016-01-03
# 3615     4489.81  2016-01-04    4      1  2016 2016-01-04 2016-01-04
# 3616     4489.81  2016-01-05    5      1  2016 2016-01-05 2016-01-05
# 3617     4489.81  2016-01-06    6      1  2016 2016-01-06 2016-01-06
# 3618     4489.81  2016-01-07    7      1  2016 2016-01-07 2016-01-07
# 3619     4489.81  2016-01-08    8      1  2016 2016-01-08 2016-01-08
# 3620     3472.12  2016-01-09    9      1  2016 2016-01-09 2016-01-09
# 3621     3472.12  2016-01-10   10      1  2016 2016-01-10 2016-01-10
#
#       dayofyear  hour
# 3612          1     0
# 3613          2     0
# 3614          3     0
# 3615          4     0
# 3616          5     0
# 3617          6     0
# 3618          7     0
# 3619          8     0
# 3620          9     0
# 3621         10     0
#
# [10 rows x 25 columns]

# %%
# Polar plot for seasonality 
ax = plt.subplot(111, projection='polar')

# Convert and plot data
df_2016 \
    .assign(day_of_year_cyclic = lambda x: x['dayofyear'].transform(lambda x: 2*np.pi*x/365.5)) \
    .pipe((sns.lineplot, 'data'), 
        x='day_of_year_cyclic', 
        y='Sea_of_Okhotsk', 
        hue='month',
        palette=sns.color_palette("husl", 12),
        ax=ax
    )

plot_year = 2016
days_per_month=[monthrange(plot_year, i)[1] for i in range(1,13)]                    #findout how many days each month has  
month_theta=(np.array(days_per_month).cumsum()-days_per_month[0]+1)*2*np.pi/365.5 #find the starting day for each month and turn it into an angle 
month_label=[month_name[i] for i in range(1,13)]
month_label=[label+'\n(Day ' +str(int(month_theta[ind]*365.5/np.pi/2)) +')' for ind,label in enumerate(month_label)]

ax.set_facecolor('white')
ax.spines.clear()
ax.set_xticks(month_theta)
ax.set_xticklabels(month_label)
ax.set_ylim(-1,1500000)
ax.set_yticks(yt:=[0,500000,1000000,1500000])
ax.set_yticklabels([str(t)+' sqkm' for t in yt], rotation = 45)
ax.set_rlabel_position(12) 
ax.xaxis.set_tick_params(which='major',pad=10)

ax.set_rorigin(-5)
ax.set_ylabel('')
ax.set_xlabel('')
ax.legend().set_visible(False)

ax.set_title('Sea of Okhotst sea ice coverage in the year 2016', va='bottom');
ax.figure.set_figwidth(12)
ax.figure.set_figheight(12)

ax.figure.savefig("Polar_plot_2016.png")

# %% [markdown]
# ## Smoothing

# %% [markdown]
# Usuall the first question of data analysis is "Can we extract general, global pattern here?"
# In time series with cyclic seasonal variation, this means that we want to smooth out this seasonality with the moving average and let the global trend manifest itself.

# %%
# Plot moving average of different length (week, month, year)
ma = [7, 30, 365]

smooth_daily_data_df = raw_df \
    .reset_index() \
    .assign(date = lambda x: x['date'].transform(pd.to_datetime))

# Smooth and plot
fig, ax = plt.subplots(4, 1, figsize=(12, 9), constrained_layout=True,sharex=True)

for i, m in enumerate(ma):

    smooth_daily_data_df[f'temp_smooth_ma_{m}'] = smooth_daily_data_df['Sea_of_Okhotsk'].rolling(window=m,center=True).mean()

    sns.lineplot(x='date', y='Sea_of_Okhotsk', label='Sea ice coverage (Signal)', data=smooth_daily_data_df,  ax=ax[i])
    sns.lineplot(x='date', y=f'temp_smooth_ma_{m}', label=f'Sea ice coverage:\n ma = {m} days', data=smooth_daily_data_df, color=NF_ORANGE, ax=ax[i])


    ax[i].legend(title='', loc='center left', bbox_to_anchor=(1, 0.5))
    ax[i].set(title='', ylabel=r'sqkm');
    
sns.lineplot(x='date', y=f'temp_smooth_ma_{m}', label=f'Sea ice coverage:\n ma = {m} days', data=smooth_daily_data_df, color=sns_c[1], ax=ax[i+1])
ax[i+1].legend(title='', loc='center left', bbox_to_anchor=(1, 0.5))
ax[i+1].set(title='', ylabel=r'sqkm');
    
    
plt.suptitle('Sea ice coverage (Daily) - Moving Average Smoothing', y=1.02);

# %% [markdown]
# In the global trend we see the decreasing amplitude and convergency to the value of 3200000 sqkm

# %% [markdown]
# ## Time Series Decomposition
#
# We can go deeper and decompose time series data into the different ingredients to understand what the sources of variation are we see in the data.
# The method `seasonal_decompose` from `statsmodels.tsa.seasonal` can help us to decompose the daily data. This method is based on moving averages and returns the **trend**, **seasonality** and **residuals** of our timeseries.
#
# The stpes inside of this function is:
# * we first check for global trends using Moving average
# * we de-trend our data by substituding the trend values from the original data
# * then we estimate seasonal component by taking averages of each season's value - for example, the effect of January is the average of all de-trended January values in the data
#
# We can define if we want to extract the yearly or monthly trends. Let's have a look at both:

# %%
df_ochotsk = raw_df[['datetime','Sea_of_Okhotsk']]
df_ochotsk.to_csv('Ochotsk.csv', encoding='utf-8', index=False)
df_ochotsk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5865 entries, 0 to 5864
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   datetime        5865 non-null   datetime64[ns]
#  1   Sea_of_Okhotsk  5865 non-null   float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 91.8 KB

# %%
# We use the parameter `period` = 365 to extract the yearly seasonality. 
from statsmodels.tsa.seasonal import seasonal_decompose
data=pd.read_csv('Ochotsk.csv',header=0,squeeze=True,index_col=[0],parse_dates=[0])
seas_decomp_yearly = seasonal_decompose(
    data,
    model='additive', 
    period=365
)
# Plot data
fig, ax = plt.subplots(4, 1, figsize=(12, 12), constrained_layout=True)
seas_decomp_yearly.observed.plot(c=sns_c[0], ax=ax[0])
ax[0].set(title='observed', ylabel=r'sqkm')
seas_decomp_yearly.trend.plot(c=sns_c[1], ax=ax[1])
ax[1].set(title='trend', ylabel=r'sqkm')
seas_decomp_yearly.seasonal.plot(c=sns_c[2], ax=ax[2])
ax[2].set(title='seasonal', ylabel=r'sqkm')
seas_decomp_yearly.resid.plot(c=sns_c[3], ax=ax[3])
ax[3].set(title='residual', ylabel=r'sqkm');
